# %%
using BenchmarkTools

using Plot

# %%
use_style!()
# Out:
# Style with:
#   - layout with fields autosize, editable, and margin

# %%
plot_x_y(([1, 2, 3], [4, 5, 6]))
# Out:
# data: [
#   "scatter with fields name, type, x, and y",
#   "scatter with fields name, type, x, and y"
# ]
#
# layout: "layout with fields autosize, editable, and margin"

# %%
plot_x_y(([1, 2, 3], [4, 5, 6]), ([1, 2, 3], [4, 5, 6]))
# Out:
# data: [
#   "scatter with fields name, type, x, and y",
#   "scatter with fields name, type, x, and y"
# ]
#
# layout: "layout with fields autosize, editable, and margin"

# %%
using Plotly

# %%
# Out:
# syntax: "<" is not a unary operator
#
# Stacktrace:
#  [1] top-level scope at In[56]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
matrix = collect(reshape(1:8, (2, 4)))
# Out:
# 2×4 Array{Int64,2}:
#  1  3  5  7
#  2  4  6  8

# %%
trace = heatmap(z = rotr90(matrix), colorscale = "Picnic")

data = [trace]

plot(data)
# Out:
# data: [
#   "heatmap with fields colorscale, type, and z"
# ]
#
# layout: "layout with fields autosize, editable, and margin"

# %%
@js
# Out:
# LoadError: UndefVarError: @js not defined
# in expression starting at In[55]:1
#
# Stacktrace:
#  [1] top-level scope
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
