# %%
using Plotly

using Plot
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-10630920503725862036\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-16652220594022097662\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-10630920503725862036\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")
# ┌ Info: Precompiling Plot [9db1e993-d40e-4a2c-9c84-e29bd56acb85]
# └ @ Base loading.jl:1278

# %% [markdown]
# ## Use style for Jupyter

# %%
plot()
# Out:
# data: []
#
# layout: "layout with field margin"

# %%
use_style!()
# Out:
# Style with:
#   - layout with fields autosize, margin, and templateaa

# %%
plot()
# Out:
# data: []
#
# layout: "layout with fields autosize, margin, and templateaa"

# %% [markdown]
# ## Extend layout

# %%
layout = Layout(title = "Title")

layout.fields
# Out:
# Dict{Symbol,Any} with 2 entries:
#   :margin => Dict(:l=>50,:b=>50,:r=>50,:t=>60)
#   :title  => "Title"

# %%
new_layout = extend_layout(layout; xaxis_title = "X-axis title")

new_layout.fields
# Out:
# Dict{Symbol,Any} with 3 entries:
#   :xaxis  => Dict{Any,Any}(:title=>"X-axis title")
#   :margin => Dict(:l=>50,:b=>50,:r=>50,:t=>60)
#   :title  => "Title"

# %%
new_layout = extend_layout(layout; yaxis_title = "Y-axis title")

new_layout.fields
# Out:
# Dict{Symbol,Any} with 3 entries:
#   :margin => Dict(:l=>50,:b=>50,:r=>50,:t=>60)
#   :title  => "Title"
#   :yaxis  => Dict{Any,Any}(:title=>"Y-axis title")

# %% [markdown]
# ## Plot vectors as lines

# %%
y_1 = [1, 2, 3]

y_2 = [4, 5, 6]

y_ = (y_1, y_2)

layout = Layout(title = "Title", xaxis_title = "X-axis title", yaxis_title = "Y-axis title")

plot_x_y(y_; layout = layout)
# Out:
# data: [
#   "scatter with fields name, type, x, and y",
#   "scatter with fields name, type, x, and y"
# ]
#
# layout: "layout with fields autosize, margin, templateaa, title, xaxis, and yaxis"

# %%
x_1 = [1, 2, 3]

y_1 = [1, 2, 3]

x_2 = [4, 5, 6]

y_2 = [4, 5, 6]

x_ = (x_1, x_2)

y_ = (y_1, y_2)

plot_x_y(
    x_,
    y_;
    title = "Title",
    xaxis_title = "X-axis title",
    yaxis_title = "Y-axis title",
)
# Out:
# data: [
#   "scatter with fields name, type, x, and y",
#   "scatter with fields name, type, x, and y"
# ]
#
# layout: "layout with fields autosize, margin, templateaa, title, xaxis, and yaxis"

# %% [markdown]
# ## Plot a matrix as heat map

# %%
matrix = collect(reshape(1:8, (2, 4)))
# Out:
# 2×4 Array{Int64,2}:
#  1  3  5  7
#  2  4  6  8

# %%
trace = heatmap(z = rotr90(matrix), colorscale = "Picnic")

data = [trace]

plot(data)
# Out:
# data: [
#   "heatmap with fields colorscale, type, and z"
# ]
#
# layout: "layout with fields autosize, margin, and templateaa"

# %% [markdown]
# ## Plot a matrix as bubble map

# %% [markdown]
# ## Plot numbers as histogram

# %% [markdown]
# ## Plot labels as pie

# %% [markdown]
# ## Plot labels as bar

# %% [markdown]
# ## Plot points in 2D

# %% [markdown]
# ## Plot points in 3D
